# %%
import pandas as pd

customers = pd.read_csv("../data/customers.csv")
print("shape : ", customers.shape)
print(customers.head())
# Out:
# shape :  (5000, 7)
#    customer_id name gender  birth_date signup_date city                 email
# 0         3293  권준서      여  1954-04-29  2020-04-26   부산  user3293@example.com
# 1         1862  박준선      F  1980-05-19  2023-09-01   서울  user1862@example.com
# 2         4955  전영경      여  1980-06-08  2024-04-30   인천  user4955@example.com
# 3         4653  한재하      M  1971-06-09  2023-08-06   서울  user4653@example.com
# 4         3331  송준연      여  1971-02-01  2023-12-20   대전  user3331@example.com

# %%
# 데이터 파일 크기 확인
import os   # 운영체제 기능 대신 해주는 라이브러리

for name in sorted(os.listdir("../data")):
    size = os.path.getsize(os.path.join("../data", name))
    print(f"{name} : {size}")
# Out:
# customers.csv : 335397
# order_items.csv : 16326730
# orders.csv : 9074503
# products.csv : 24106
# web_logs.csv : 54464850

# %%
# customers.csv 파일 읽기 <= pandas library 사용
import pandas as pd

# read_csv -> DataFrame(행x열 : 표, 2차원 데이터) : pandas library 데이터(행열)를 저장하는 방법
# customers : DataFrame object
customers = pd.read_csv("../data/customers.csv")
print(customers.shape)
print(customers.head())    # head(숫자) : 위에서 몇 개 조회.

# (5000, 7) --> row(행): 5000, col(열): 7
# pandas는 column 단위 저장.
# column 하나를 Series라고 함.
# Series를 다 연결하면 DataFrame이 됨.
# Out:
# (5000, 7)
#    customer_id name gender  birth_date signup_date city                 email
# 0         3293  권준서      여  1954-04-29  2020-04-26   부산  user3293@example.com
# 1         1862  박준선      F  1980-05-19  2023-09-01   서울  user1862@example.com
# 2         4955  전영경      여  1980-06-08  2024-04-30   인천  user4955@example.com
# 3         4653  한재하      M  1971-06-09  2023-08-06   서울  user4653@example.com
# 4         3331  송준연      여  1971-02-01  2023-12-20   대전  user3331@example.com

# %%
customers.head(20)
# Out:
#     customer_id name gender  birth_date signup_date city                 email
# 0          3293  권준서      여  1954-04-29  2020-04-26   부산  user3293@example.com
# 1          1862  박준선      F  1980-05-19  2023-09-01   서울  user1862@example.com
# 2          4955  전영경      여  1980-06-08  2024-04-30   인천  user4955@example.com
# 3          4653  한재하      M  1971-06-09  2023-08-06   서울  user4653@example.com
# 4          3331  송준연      여  1971-02-01  2023-12-20   대전  user3331@example.com
# 5          1992  최현우      여  1999-08-31  2021-06-22   고양  user1992@example.com
# 6          3499  전선태      남  2005-03-12  2021-07-02   광주                   NaN
# 7          2183  장예성      M  1992-03-22  2021-02-19   수원  user2183@example.com
# 8          5090  권재현      M  1972-08-26  2020-10-02   서울                   NaN
# 9          2209  홍준영      M  1976-06-16  2024-03-10   수원  user2209@example.com
# 10         5055  윤수현      F  1972-03-11  2021-05-20   서울  user5055@example.com
# ...

# %%
import pandas as pd

# %%
# 데이터 로딩
orders_df = pd.read_csv("../data/orders.csv")
orders_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   order_id        200000 non-null  int64
#  1   customer_id     200000 non-null  int64
#  2   order_datetime  198067 non-null  str
#  3   channel         200000 non-null  str
#  4   status          200000 non-null  str
# dtypes: int64(2), str(3)
# memory usage: 13.4 MB

# %%
con1 = orders_df["channel"] == "web"
con2 = orders_df["status"] == "delivered"
seq = orders_df[con1 & con2]
seq.shape[0]
# Out:
# 60455

# %%
sql_condition = "channel=='web' & status=='delivered'"
seqq = orders_df.query(sql_condition)
seqq.shape[0]
# Out:
# 60455

# %%
# 직접 해 보기

# %%
# 여러 조건을 자유롭게 조합
# 주문 경로 'web', 주문 상태 '배송완료', 6월 주문
con1 = orders_df["channel"] == "web"
con2 = orders_df["status"] == "delivered"
con3 = orders_df["order_datetime"].str.contains("-06-")
orders_df[con1&con2&con3]
# Out:
#         order_id  customer_id       order_datetime channel     status
# 9         140227         3186  2024-06-12 19:59:48     web  delivered
# 20         68062         5254  2024-06-23 19:15:09     web  delivered
# 70         55725         2403  2024-06-07 10:47:32     web  delivered
# 90        128047         5509  2024-06-07 22:16:54     web  delivered
# 92        103764         4823  2024-06-30 11:34:29     web  delivered
# ...          ...          ...                  ...     ...        ...
# 199922    128829         5464  2024-06-27 18:17:35     web  delivered
# 199928     81890         4593  2024-06-26 13:48:25     web  delivered
# 199936     92836         3432  2024-06-08 11:36:09     web  delivered
# 199963    124189         4823  2024-06-05 05:00:04     web  delivered
# 199968     63543         4201  2024-06-01 09:30:50     web  delivered
#
# [13077 rows x 5 columns]

# %%
orders_df["order_datetime"][1].split("-")[1] == "06"
# Out:
# False

# %%
orders_df = pd.read_csv("../data/orders.csv", parse_dates=["order_datetime"])
orders_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   order_id        200000 non-null  int64
#  1   customer_id     200000 non-null  int64
#  2   order_datetime  198067 non-null  datetime64[us]
#  3   channel         200000 non-null  str
#  4   status          200000 non-null  str
# dtypes: datetime64[us](1), int64(2), str(2)
# memory usage: 9.7 MB

# %%
con1 = orders_df["channel"] == "web"
con2 = orders_df["status"] == "delivered"
con3 = orders_df["order_datetime"].dt.month == 6.0

seq3 = orders_df[con1&con2&con3]
seq3.shape[0]
# Out:
# 13077
